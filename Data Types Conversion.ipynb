# %% [markdown]
# # Data Types Conversion

# %%
num_int = 7

type(num_int)
# Out:
# int

# %%
num_str = '7'

type(num_str)
# Out:
# str

# %%
#it throws error
num_sum = num_int + num_str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 num_sum = num_int + num_str
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#converting string to integer
num_str_conv = int(num_str)

# %%
num_sum = num_int + num_str_conv
print(num_sum)
# Out:
# 14

# %%
type(num_sum)
# Out:
# int

# %%
#converting list to tuple
list_type = [1 , 2 , 3 , 4 , 5]

# %%
#converting list to sets - it only return unique values
list_type = [1 , 2 , 3 , 3 , 2 , 1]

# %%
tuple(list_type)
# Out:
# (1, 2, 3, 4, 5)

# %%
set(list_type)
# Out:
# {1, 2, 3}

# %%
#converting dictionary to list
dict_type = {'name' : 'Gururaj' , 'age' : 20 , 'gender' : 'male'}

# %%
list(dict_type.values())
# Out:
# ['Gururaj', 20, 'male']

# %%
#coverting long strings into list

string = "My Name Is Gururaj Sharma"

list(string)
# Out:
# ['M',
#  'y',
#  ' ',
#  'N',
#  'a',
#  'm',
#  'e',
#  ' ',
#  'I',
#  's',
#  ' ',
#  'G',
#  'u',
#  'r',
#  'u',
#  'r',
#  'a',
#  'j',
#  ' ',
#  'S',
#  'h',
#  'a',
#  'r',
#  'm',
#  'a']
